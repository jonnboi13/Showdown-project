# %%
import importlib
import src.analytics
importlib.reload(src.analytics)

from src.analytics import get_tier_lazyframe, compute_pokemon_stats, compute_meta_summary
print("Successfully imported!")
# Out:
# Successfully imported!

# %%
# Cell 1: Setup and Path Resolution
import sys
from pathlib import Path
from IPython.display import display
import polars as pl

# Ensure Python can find the 'src' directory from the 'notebooks' folder
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.analytics import get_tier_lazyframe, compute_pokemon_stats, compute_meta_summary

# %%
# Cell 2: Load the LazyFrame and Check Global Meta Summary
tier = "gen9ou"
lf = get_tier_lazyframe(tier)

meta_summary = compute_meta_summary(lf)
print("--- Tier Meta Summary ---")
for key, value in meta_summary.items():
    print(f"{key}: {value:,.2f}" if isinstance(value, float) else f"{key}: {value:,}")
# Out:
# --- Tier Meta Summary ---
# total_player_records: 204
# avg_turns: 24.21
# avg_rating: 1,187.86

# %%
# Cell 3: Compute and Display Pokémon Usage & Win Rates
# Test with a minimum rating filter (e.g., 1200 or 1500)
stats_df = compute_pokemon_stats(lf, min_rating=1000)

print(f"Total unique Pokémon tracked: {len(stats_df)}")
display(stats_df.head(15))
# Out:
# Total unique Pokémon tracked: 229
# shape: (15, 6)
# ┌────────────────────┬─────────────┬──────┬────────────┬────────────────┬──────────┐
# │ pokemon            ┆ appearances ┆ wins ┆ avg_rating ┆ usage_rate_pct ┆ win_rate │
# │ ---                ┆ ---         ┆ ---  ┆ ---        ┆ ---            ┆ ---      │
# │ str                ┆ u32         ┆ u32  ┆ f64        ┆ f64            ┆ f64      │
# ╞════════════════════╪═════════════╪══════╪════════════╪════════════════╪══════════╡
# │ Gholdengo          ┆ 38          ┆ 21   ┆ 1198.0     ┆ 21.6           ┆ 0.55     │
# │ Great Tusk         ┆ 37          ┆ 21   ┆ 1213.5     ┆ 21.0           ┆ 0.57     │
# │ Gliscor            ┆ 29          ┆ 15   ┆ 1205.8     ┆ 16.5           ┆ 0.52     │
# │ Kingambit          ┆ 27          ┆ 16   ┆ 1257.9     ┆ 15.3           ┆ 0.59     │
# │ Corviknight        ┆ 24          ┆ 14   ┆ 1183.4     ┆ 13.6           ┆ 0.58     │
# │ …                  ┆ …           ┆ …    ┆ …          ┆ …              ┆ …        │
# │ Ogerpon-Wellspring ┆ 19          ┆ 7    ┆ 1265.9     ┆ 10.8           ┆ 0.37     │
# │ Dragonite          ┆ 18          ┆ 7    ┆ 1190.4     ┆ 10.2           ┆ 0.39     │
# │ Zamazenta          ┆ 17          ┆ 12   ┆ 1246.2     ┆ 9.7            ┆ 0.71     │
# │ Alomomola          ┆ 17          ┆ 9    ┆ 1208.8     ┆ 9.7            ┆ 0.53     │
# │ Ceruledge          ┆ 16          ┆ 9    ┆ 1177.4     ┆ 9.1            ┆ 0.56     │
# └────────────────────┴─────────────┴──────┴────────────┴────────────────┴──────────┘

# %%
# Cell 4: Inspect Raw Match Records (Sanity Check)
sample_records = lf.limit(3).collect()
display(sample_records)
# Out:
# shape: (3, 8)
# ┌───────────────┬────────────┬────────┬───────────────┬───────┬───────┬───────────────┬────────────┐
# │ match_id      ┆ format     ┆ rating ┆ player        ┆ won   ┆ turns ┆ pokemon       ┆ uploadtime │
# │ ---           ┆ ---        ┆ ---    ┆ ---           ┆ ---   ┆ ---   ┆ ---           ┆ ---        │
# │ str           ┆ str        ┆ i32    ┆ str           ┆ bool  ┆ i32   ┆ list[str]     ┆ i32        │
# ╞═══════════════╪════════════╪════════╪═══════════════╪═══════╪═══════╪═══════════════╪════════════╡
# │ gen9ou-267616 ┆ [Gen 9] OU ┆ 1066   ┆ gkjjhkhkjhkh  ┆ true  ┆ 17    ┆ ["Hatterene,  ┆ 1788634380 │
# │ 4667          ┆            ┆        ┆               ┆       ┆       ┆ F", "Great    ┆            │
# │               ┆            ┆        ┆               ┆       ┆       ┆ Tusk",…       ┆            │
# │ gen9ou-267616 ┆ [Gen 9] OU ┆ 1066   ┆ Ares_1997     ┆ false ┆ 17    ┆ ["Zamazenta-* ┆ 1788634380 │
# │ 4667          ┆            ┆        ┆               ┆       ┆       ┆ ", "Iron      ┆            │
# │               ┆            ┆        ┆               ┆       ┆       ┆ Hands", …     ┆            │
# │ gen9ou-267616 ┆ [Gen 9] OU ┆ 1081   ┆ bushidomichae ┆ true  ┆ 0     ┆ ["Corviknight ┆ 1788634296 │
# │ 5803          ┆            ┆        ┆ l             ┆       ┆       ┆ , F",         ┆            │
# │               ┆            ┆        ┆               ┆       ┆       ┆ "Kommo-o, F…  ┆            │
# └───────────────┴────────────┴────────┴───────────────┴───────┴───────┴───────────────┴────────────┘
